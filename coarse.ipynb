# %%
import numpy as np
from acrobat import Acrobat
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random

# %%
ac = Acrobat()
for _ in range(200):
    ac.do_action(random.randint(-1,1))

ac.animate(25)
