# %%
import numpy as np
from acrobat import Acrobat, Tiling, Sarsa
import acrobat as ac
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random

# %%
acro = Acrobat()
tils = ac.init_tilings()

sarsa = Sarsa(acro, tils=tils)

# %%
sarsa.run(1)
# Out:
# Trial: 0

# %%
plt.plot(sarsa.steps)

# %%
acro.animate()
